# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/gdrive')

# Import pandas
import pandas as pd
# Used to interact with directories
import os
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# First, we need to import the data set with the harvested tweets.

# %%
# Takes all .csv files in a directory and write it into a single Pandas DataFrame
directory_path= "/gdrive/MyDrive/TwitterData_GroupB/Data/Tweets/"

# Create empty DataFrame to fill
tweets = pd.DataFrame()

# iterate over specified directory
for filename in os.listdir(directory_path):
    # set file path
    file_path = os.path.join(directory_path,filename)
    if os.path.isfile(file_path):
      # check if file is a .csv file
      if file_path.endswith('.csv'):
        print(f"Loading: {file_path}.")
        # Read csv into a Pandas DataFrame
        tweets_enkel = pd.read_csv(file_path, encoding='utf-8', engine='python') # specify encoding and engine to not get DtypeWarning
        # Concatenate tweets from single file to Tweets DataFrame
        tweets= pd.concat([tweets, tweets_enkel])



tweets.info()
# Out:
# Loading: /gdrive/MyDrive/TwitterData_GroupB/Data/Tweets/dutchTweets1.csv.
# Loading: /gdrive/MyDrive/TwitterData_GroupB/Data/Tweets/dutchTweets2.csv.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1239546 entries, 0 to 610057
# Data columns (total 83 columns):
#  #   Column                                 Non-Null Count    Dtype
# ---  ------                                 --------------    -----
#  0   id                                     1239546 non-null  int64
#  1   conversation_id                        1239546 non-null  int64
#  2   referenced_tweets.replied_to.id        742050 non-null   float64
#  3   referenced_tweets.retweeted.id         300169 non-null   float64
#  4   referenced_tweets.quoted.id            37537 non-null    float64
#  5   author_id                              1239546 non-null  int64
#  6   in_reply_to_user_id                    750370 non-null   float64
#  7   in_reply_to_username                   709298 non-null   object
#  8   retweeted_user_id                      300169 non-null   float64
#  9   retweeted_username                     300169 non-null   object
#  10  quoted_user_id                         37537 non-null    float64
#  11  quoted_username                        37537 non-null    object
#  12  created_at                             1239546 non-null  object
#  13  text                                   1239546 non-null  object
#  14  lang                                   1239546 non-null  object
#  15  source                                 0 non-null        float64
#  16  public_metrics.impression_count        1239546 non-null  int64
#  17  public_metrics.reply_count             1239546 non-null  int64
#  18  public_metrics.retweet_count           1239546 non-null  int64
#  19  public_metrics.quote_count             1239546 non-null  int64
#  20  public_metrics.like_count              1239546 non-null  int64
#  21  reply_settings                         1239546 non-null  object
#  22  edit_history_tweet_ids                 1239546 non-null  object
#  23  edit_controls.edits_remaining          1239546 non-null  int64
#  24  edit_controls.editable_until           1239546 non-null  object
#  25  edit_controls.is_edit_eligible         1239546 non-null  bool
#  26  possibly_sensitive                     1239546 non-null  bool
#  27  withheld.scope                         0 non-null        float64
#  28  withheld.copyright                     246 non-null      object
#  29  withheld.country_codes                 246 non-null      object
#  30  entities.annotations                   0 non-null        float64
#  31  entities.cashtags                      246 non-null      object
#  32  entities.hashtags                      138717 non-null   object
#  33  entities.mentions                      883463 non-null   object
#  34  entities.urls                          369934 non-null   object
#  35  context_annotations                    192080 non-null   object
#  36  attachments.media                      191878 non-null   object
#  37  attachments.media_keys                 191878 non-null   object
#  38  attachments.poll.duration_minutes      928 non-null      float64
#  39  attachments.poll.end_datetime          928 non-null      object
#  40  attachments.poll.id                    928 non-null      float64
#  41  attachments.poll.options               928 non-null      object
#  42  attachments.poll.voting_status         928 non-null      object
#  43  attachments.poll_ids                   928 non-null      object
#  44  author.id                              1239546 non-null  int64
#  45  author.created_at                      1239546 non-null  object
#  46  author.username                        1239546 non-null  object
#  47  author.name                            1239506 non-null  object
#  48  author.description                     1030580 non-null  object
#  49  author.entities.description.cashtags   890 non-null      object
#  50  author.entities.description.hashtags   127968 non-null   object
#  51  author.entities.description.mentions   88299 non-null    object
#  52  author.entities.description.urls       50220 non-null    object
#  53  author.entities.url.urls               279508 non-null   object
#  54  author.url                             279508 non-null   object
#  55  author.location                        739229 non-null   object
#  56  author.pinned_tweet_id                 514497 non-null   float64
#  57  author.profile_image_url               1239511 non-null  object
#  58  author.protected                       1239546 non-null  bool
#  59  author.public_metrics.followers_count  1239546 non-null  int64
#  60  author.public_metrics.following_count  1239546 non-null  int64
#  61  author.public_metrics.listed_count     1239546 non-null  int64
#  62  author.public_metrics.tweet_count      1239546 non-null  int64
#  63  author.verified                        1239546 non-null  bool
#  64  author.verified_type                   610058 non-null   object
#  65  author.withheld.scope                  0 non-null        float64
#  66  author.withheld.copyright              0 non-null        float64
#  67  author.withheld.country_codes          187 non-null      object
#  68  geo.coordinates.coordinates            53 non-null       object
#  69  geo.coordinates.type                   53 non-null       object
#  70  geo.country                            20100 non-null    object
#  71  geo.country_code                       20100 non-null    object
#  72  geo.full_name                          20100 non-null    object
#  73  geo.geo.bbox                           20100 non-null    object
#  74  geo.geo.type                           20100 non-null    object
#  75  geo.id                                 20100 non-null    object
#  76  geo.name                               20100 non-null    object
#  77  geo.place_id                           20100 non-null    object
#  78  geo.place_type                         20100 non-null    object
#  79  matching_rules                         0 non-null        float64
#  80  __twarc.retrieved_at                   1239546 non-null  object
#  81  __twarc.url                            1239546 non-null  object
#  82  __twarc.version                        1239546 non-null  object
# dtypes: bool(4), float64(15), int64(14), object(50)
# memory usage: 761.3+ MB

# %% [markdown]
# Then we check the first 5 rows to get a sense of how the data looks

# %%
tweets.head()
# Out:
#                     id      conversation_id  referenced_tweets.replied_to.id  \
# 0  1641773164387528704  1641773164387528704                              NaN
# 1  1641773163523522560  1641773163523522560                              NaN
# 2  1641773160310755328  1641773160310755328                              NaN
# 3  1641773156573618176  1641449801366781953                     1.641450e+18
# 4  1641773152286961664  1641701863153360896                     1.641702e+18
#
#    referenced_tweets.retweeted.id  referenced_tweets.quoted.id  \
# 0                    1.641363e+18                          NaN
# 1                             NaN                          NaN
# 2                    1.641519e+18                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
#
#              author_id  in_reply_to_user_id in_reply_to_username  \
# 0            393582704                  NaN                  NaN
# 1  1103414720420290562                  NaN                  NaN
# 2            470999569                  NaN                  NaN
# 3             95203647         2.776187e+09           VillaVega5
# 4           1705279506         1.211371e+08               hcssnl
#
#    retweeted_user_id retweeted_username  ...  geo.geo.bbox geo.geo.type  \
# 0       1.460051e+18     MelissaKampers  ...           NaN          NaN
# 1                NaN                NaN  ...           NaN          NaN
# 2       3.103261e+06         volkskrant  ...           NaN          NaN
# 3                NaN                NaN  ...           NaN          NaN
# 4                NaN                NaN  ...           NaN          NaN
#
#   geo.id geo.name geo.place_id  geo.place_type  matching_rules  \
# 0    NaN      NaN          NaN             NaN             NaN
# 1    NaN      NaN          NaN             NaN             NaN
# 2    NaN      NaN          NaN             NaN             NaN
# 3    NaN      NaN          NaN             NaN             NaN
# 4    NaN      NaN          NaN             NaN             NaN
#
#         __twarc.retrieved_at  \
# 0  2023-03-31T12:03:32+00:00
# 1  2023-03-31T12:03:32+00:00
# 2  2023-03-31T12:03:32+00:00
# 3  2023-03-31T12:03:32+00:00
# 4  2023-03-31T12:03:32+00:00
#
#                                          __twarc.url  __twarc.version
# 0  https://api.twitter.com/2/tweets/search/recent...           2.13.0
# 1  https://api.twitter.com/2/tweets/search/recent...           2.13.0
# 2  https://api.twitter.com/2/tweets/search/recent...           2.13.0
# 3  https://api.twitter.com/2/tweets/search/recent...           2.13.0
# 4  https://api.twitter.com/2/tweets/search/recent...           2.13.0
#
# [5 rows x 83 columns]

# %% [markdown]
# Next, since we are only interested in tweets which are geotaged, we filter out all tweets that do not have a geotag. Again, we check the dataset to see how many geotagged tweets we harvested, and how many unique conversations this subset has.

# %%
# Dropping All Tweets without geolocation
geoTweets = tweets.dropna(subset=['geo.geo.bbox'])

# Check Dataset Info
print(geoTweets.shape)
print(geoTweets['conversation_id'].nunique())
# Out:
# (20100, 83)
# 15630

# %% [markdown]
# Now that we have assessed the raw dataset, it is time to build our data pipeline. First, I will program a function that will unpack a list of datasets, filter out ungeotagged tweets and other info we do not need and return a dataframe with all the info we need.

# %%
# Function to Unpack Geotagged Tweets into 1 Dataframe
def unpackTweets(datasetList, attributeList):
    # Create Empty Dataframe
    resultDF = pd.DataFrame()
    # Create List of Attributes to Keep
    attributes = attributeList
    # Loop Through Dataset List
    for dataset in datasetList:
        # Create Dataframe from Dataset
        df = pd.read_csv(dataset)
        # Drop Tweets without Geolocation
        df = df.dropna(subset=['geo.geo.bbox'])
        # Drop Tweets without Reply Info
        df = df.dropna(subset=['in_reply_to_user_id'])
        # Keep Only Specified Attributes
        df = df.loc[:, attributes]
        # Change Type of Column
        df['in_reply_to_user_id'] = df['in_reply_to_user_id'].astype('int64')
        # Concatenate Dataframes
        resultDF = pd.concat([resultDF, df], axis=0)
    return resultDF

# %% [markdown]
# Next, we are going to use this function to filter our original dataset into a dataset we can use for our analysis. The columns we are interested in are: 'author_id', 'text', 'conversation_id', 'in_reply_to_user_id', 'geo.geo.bbox'.

# %%
# Make List of Attributes to Keep
attributesToFilter = ['author_id', 'text', 'conversation_id', 'in_reply_to_user_id', 'geo.geo.bbox']
# Make List of Datasets to Unpack
#datasetsToUnpack = ['dutchTweets1.csv']
datasetsToUnpack = [file_path]
# Create Project Dataset
tweetData = unpackTweets(datasetsToUnpack, attributesToFilter)
# Check Dataset Info
print(tweetData.shape)
tweetData.info()
# Out:
# <ipython-input-12-8f8d4659b6d4>:10: DtypeWarning: Columns (28,29,31,39,41,42,43,49,67,68,69) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(dataset)
# (7558, 5)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7558 entries, 59 to 610030
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   author_id            7558 non-null   int64
#  1   text                 7558 non-null   object
#  2   conversation_id      7558 non-null   int64
#  3   in_reply_to_user_id  7558 non-null   int64
#  4   geo.geo.bbox         7558 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 354.3+ KB

# %% [markdown]
# Next, we want to remove rows that are have a unique 'conversation_id' value, so that we have a dataset with (small) conversations instead of single tweets.

# %%
def filterOutUniqueConversations(df, column):
    mask = df[column].duplicated(keep=False)

    return df[mask]

# %% [markdown]
# Also, we need to check whether we have enough unique authors

# %%
usefulTweets = filterOutUniqueConversations(tweetData, 'conversation_id')
print(usefulTweets.shape)
print(usefulTweets['author_id'].nunique())
print(usefulTweets['in_reply_to_user_id'].nunique())
usefulTweets.head()
# Out:
# (3045, 5)
# 842
# 1665
#                 author_id                                               text  \
# 59              219069852  @ONevermind2023 Ik ken ze altijd een softblock...
# 1088           1032894392  @Ikhounietvanvis @AkbasPinar1980 En dan “Ah, M...
# 1121            324253579  @ingevanwolferen @delibrije In dat geval is mi...
# 1525  1442171543463682049  @GrunnegsWief Zeker! Ik had ‘m niet beter kunn...
# 2177           1032894392  @Ikhounietvanvis @AkbasPinar1980 Je wilt niet ...
#
#           conversation_id  in_reply_to_user_id  \
# 59    1644673059264122881  1608857537226358784
# 1088  1644726752470618114  1248177989831049216
# 1121  1644687598978252800            228155039
# 1525  1644440668834525223  1189264143624343552
# 2177  1644726752470618114  1248177989831049216
#
#                                         geo.geo.bbox
# 59    [5.0857107, 52.3846363, 5.6059368, 52.6916409]
# 1088  [2.9588621, 50.9160108, 3.0884673, 50.9993029]
# 1121   [4.9702867, 52.0262429, 5.1952468, 52.142137]
# 1525  [6.0033058, 52.4404911, 6.2105671, 52.5879383]
# 2177  [2.9588621, 50.9160108, 3.0884673, 50.9993029]

# %% [markdown]
# Next, we are only interested in the tweets for which we have both the geolocation of the author and the person he/she replies to. Thus, we need to filter the dataframe in a way that we only keep rows for which both the author_id and in_reply_to_user_id are present in the dataframe, although they do not need to be in the same row.

# %%
# Function to Filter Out Unlocated Users
def filterOutUnlocatedUsers(df1, df2):
    # Loop Through in_reply_to_user_id Column
    for id in df1['in_reply_to_user_id']:
        # Check if ID is in author_id Column
        if id not in df2['author_id'].values:
            # Drop Row if not
            df1 = df1[df1['in_reply_to_user_id'] != id]
    return df1

# Function to Filter Out Users Who Reply to Themselves
def filterOutSelfReplies(df):
    # Loop Through Rows in Dataframe
    for index, row in df.iterrows():
        # Get in_reply_to_user_id and author_id for Row
        in_reply_to_user_id = row['in_reply_to_user_id']
        author_id = row['author_id']
        # Check if Self-Reply
        if in_reply_to_user_id == author_id:
            # Drop Row if Self-Reply
            df.drop(index, inplace=True)
    return df

# %% [markdown]
# Testing the dataset again

# %%
usefulTweets = filterOutUnlocatedUsers(usefulTweets, tweetData)
print(usefulTweets.shape)
print(usefulTweets['author_id'].nunique())
print('')
usefulTweets = filterOutSelfReplies(usefulTweets)
print(usefulTweets.shape)
print(usefulTweets['author_id'].nunique())

usefulTweets.head()
# Out:
# (426, 5)
# 245
#
# (281, 5)
# 174
#                author_id                                               text  \
# 2258  940899377543110656  @wardmarkey @Ikhounietvanvis Kom es langs he, ...
# 2364          1032894392  @AkbasPinar1980 @Ikhounietvanvis Daar ben ik a...
# 6601           495914854   @MrsSandvrouw Ik ben het helemaal met je eens!!!
# 8149            14264386   @erwblo 🤷🏼‍♂️\n\nHou ik me totaal niet mee bezig
# 8202              713333  @remkusdevries Ik weet niet of het aantal klom...
#
#           conversation_id  in_reply_to_user_id  \
# 2258  1644726752470618114           1032894392
# 2364  1644726752470618114   940899377543110656
# 6601  1644682823343677441   707643871379988480
# 8149  1644701882793828352               713333
# 8202  1644701882793828352             14264386
#
#                                         geo.geo.bbox
# 2258  [5.2121062, 50.8677279, 5.4145591, 50.9815265]
# 2364  [2.9588621, 50.9160108, 3.0884673, 50.9993029]
# 6601   [6.7559955, 52.1611799, 6.981174, 52.2855112]
# 8149  [5.7298822, 53.0457272, 5.9496796, 53.2433434]
# 8202  [4.7288999, 52.2782266, 5.0792072, 52.4312289]

# %% [markdown]
# Next, we need to add a column for the location of the recipee of the tweet, so that each tweet now has both user IDs of the engagement and the location for each user.

# %%
def addReceiverLocation(df1, df2):
    # Rename geo.geo.bbox Column
    df1.rename(columns={'geo.geo.bbox': 'sender_location'}, inplace=True)
    # Create Empty List to Store Receiver Locations
    receiverLocations = []
    # Loop Through Rows in Dataframe
    for index1, row1 in df1.iterrows():
        # Get Receiver ID
        receiverID = row1['in_reply_to_user_id']
        # Get Receiver Location
        recieverLocation = []
        for index2, row2 in df2.iterrows():
            if receiverID == row2['author_id']:
                recieverLocation = row2['geo.geo.bbox']
                break
        # Append Receiver Location to List
        receiverLocations.append(recieverLocation)
    # Add Receiver Locations to Dataframe
    df1['receiver_location'] = receiverLocations
    return df1

# %% [markdown]
# Test the dataset again

# %%
usefultweets = addReceiverLocation(usefulTweets, tweetData)
# Assess Dataset
print(usefulTweets.shape)
print(usefulTweets['author_id'].nunique())

usefulTweets.head()
# Out:
# (281, 6)
# 174
#                author_id                                               text  \
# 2258  940899377543110656  @wardmarkey @Ikhounietvanvis Kom es langs he, ...
# 2364          1032894392  @AkbasPinar1980 @Ikhounietvanvis Daar ben ik a...
# 6601           495914854   @MrsSandvrouw Ik ben het helemaal met je eens!!!
# 8149            14264386   @erwblo 🤷🏼‍♂️\n\nHou ik me totaal niet mee bezig
# 8202              713333  @remkusdevries Ik weet niet of het aantal klom...
#
#           conversation_id  in_reply_to_user_id  \
# 2258  1644726752470618114           1032894392
# 2364  1644726752470618114   940899377543110656
# 6601  1644682823343677441   707643871379988480
# 8149  1644701882793828352               713333
# 8202  1644701882793828352             14264386
#
#                                      sender_location  \
# 2258  [5.2121062, 50.8677279, 5.4145591, 50.9815265]
# 2364  [2.9588621, 50.9160108, 3.0884673, 50.9993029]
# 6601   [6.7559955, 52.1611799, 6.981174, 52.2855112]
# 8149  [5.7298822, 53.0457272, 5.9496796, 53.2433434]
# 8202  [4.7288999, 52.2782266, 5.0792072, 52.4312289]
#
#                                    receiver_location
# 2258  [2.9588621, 50.9160108, 3.0884673, 50.9993029]
# 2364  [5.2121062, 50.8677279, 5.4145591, 50.9815265]
# 6601  [6.8263158, 52.6327357, 7.0926136, 52.8729716]
# 8149  [4.7288999, 52.2782266, 5.0792072, 52.4312289]
# 8202  [5.7298822, 53.0457272, 5.9496796, 53.2433434]

# %% [markdown]
# Now we have developed the first pipeline for the geospatial analysis, so let's create one function that takes in a raw dataset and returns a dataframe that is ready for our geospatial analysis

# %%
def dataPipeline(rawData, AttributesToFilter):
    # Unpack Tweets
    rawDf = unpackTweets(rawData, AttributesToFilter)
    # Filter Out Unique Conversations
    df = filterOutUniqueConversations(rawDf, 'conversation_id')
    # Filter Out Unlocated Users
    df = filterOutUnlocatedUsers(df, rawDf)
    # Filter Out Self-Replies
    df = filterOutSelfReplies(df)
    # Add Receiver Location
    df = addReceiverLocation(df, rawDf)
    return df

# %% [markdown]
# Let's test the data pipeline function

# %%
inputData = dataPipeline(datasetsToUnpack, attributesToFilter)

# Assess Dataset
print(inputData.shape)
print(inputData['author_id'].nunique())

inputData.head()
# Out:
# <ipython-input-12-8f8d4659b6d4>:10: DtypeWarning: Columns (28,29,31,39,41,42,43,49,67,68,69) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(dataset)
# (281, 6)
# 174
#                author_id                                               text  \
# 2258  940899377543110656  @wardmarkey @Ikhounietvanvis Kom es langs he, ...
# 2364          1032894392  @AkbasPinar1980 @Ikhounietvanvis Daar ben ik a...
# 6601           495914854   @MrsSandvrouw Ik ben het helemaal met je eens!!!
# 8149            14264386   @erwblo 🤷🏼‍♂️\n\nHou ik me totaal niet mee bezig
# 8202              713333  @remkusdevries Ik weet niet of het aantal klom...
#
#           conversation_id  in_reply_to_user_id  \
# 2258  1644726752470618114           1032894392
# 2364  1644726752470618114   940899377543110656
# 6601  1644682823343677441   707643871379988480
# 8149  1644701882793828352               713333
# 8202  1644701882793828352             14264386
#
#                                      sender_location  \
# 2258  [5.2121062, 50.8677279, 5.4145591, 50.9815265]
# 2364  [2.9588621, 50.9160108, 3.0884673, 50.9993029]
# 6601   [6.7559955, 52.1611799, 6.981174, 52.2855112]
# 8149  [5.7298822, 53.0457272, 5.9496796, 53.2433434]
# 8202  [4.7288999, 52.2782266, 5.0792072, 52.4312289]
#
#                                    receiver_location
# 2258  [2.9588621, 50.9160108, 3.0884673, 50.9993029]
# 2364  [5.2121062, 50.8677279, 5.4145591, 50.9815265]
# 6601  [6.8263158, 52.6327357, 7.0926136, 52.8729716]
# 8149  [4.7288999, 52.2782266, 5.0792072, 52.4312289]
# 8202  [5.7298822, 53.0457272, 5.9496796, 53.2433434]

# %% [markdown]
# Now we only need to add a function that makes the tweets ready for NLP.
